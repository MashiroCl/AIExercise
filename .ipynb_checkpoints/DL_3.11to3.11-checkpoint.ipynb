# %%
import d2lzh as d2l
from mxnet import autograd,gluon,nd
from mxnet.gluon import data as gdata, loss as gloss,nn

# %%
n_train,n_test,true_w,true_b=100,100,[1.2,-3.4,5.6],5
features=nd.random.normal(shape=(n_train+n_test,1))
poly_features=nd.concat(features,nd.power(features,2),nd.power(features,3))
labels=(true_w[0]*poly_features[:,0]+true_w[1]*poly_features[:,1]+true_w[2]*poly_features[:,2]+true_b)
labels+=nd.random.normal(scale=0.1,shape=labels.shape)

# %%
features[:2],poly_features[:2],labels[:2]
# Out:
# (
#  [[-0.38509098]
#   [-0.98780406]]
#  <NDArray 2x1 @cpu(0)>,
#  [[-0.38509098  0.14829506 -0.05710709]
#   [-0.98780406  0.9757568  -0.9638566 ]]
#  <NDArray 2x3 @cpu(0)>,
#  [ 3.646205 -4.962129]
#  <NDArray 2 @cpu(0)>)

# %%
def semilogy(x_vals,y_vals,x_label,y_label,x2_vals=None,y2_vals=None,legend=None,figsize=(3.5,2.5)):
    d2l.set_figsize(figsize)
    d2l.plt.xlabel(x_label)
    d2l.plt.ylabel(y_label)
    d2l.plt.semilogy(x_vals,y_vals)
    if x2_vals and y2_vals:
        d2l.plt.semilogy(x2_vals,y2_vals,linestyle=':')
        d2l.plt.legend(legend)

# %%
num_epochs,loss=100,gloss.L2Loss()

def fit_and_plot(train_features,test_features,train_labels,test_labels):
    net=nn.Sequential()
    net.add(nn.Dense(1))
    net.initialize()
    batch_size=min(10,train_labels.shape[0])
    train_iter=gdata.DataLoader(gdata.ArrayDataset(train_features,train_labels),batch_size,shuffle=True)
    trainer=gluon.Trainer(net.collect_params(),'sgd',{'learning_rate':0.01})
    train_ls,test_ls=[],[]
    for _ in range(num_epochs):
        for X,y in train_iter:
            with autograd.record():
                l=loss(net(X),y)
            l.backward()
            trainer.step(batch_size)
        train_ls.append(loss(net(train_features),train_labels).mean().asscalar())
        test_ls.append(loss(net(test_features),test_labels).mean().asscalar())
        print("each epoch:train loss",train_ls[-1],'test losss',test_ls[-1])
    print('final epoch:train loss', train_ls[-1],'test loss',test_ls[-1])
    semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'loss',
             range(1, num_epochs + 1), test_ls, ['train', 'test'])
    print('weight:',net[0].weight.data().asnumpy(),'\nbias:',net[0].bias.data().asnumpy())

# %%
fit_and_plot(poly_features[:n_train,:],poly_features[n_train:,:],labels[:n_train],labels[n_train:])
# Out:
# each epoch:train loss 15.579154 test losss 12.17559
# each epoch:train loss 10.349907 test losss 11.478883
# each epoch:train loss 8.757113 test losss 10.80677
# each epoch:train loss 7.4272547 test losss 7.930829
# each epoch:train loss 6.371597 test losss 7.161652
# each epoch:train loss 5.787525 test losss 6.966814
# each epoch:train loss 4.9419823 test losss 5.2166166
# each epoch:train loss 4.676664 test losss 5.6102467
# each epoch:train loss 3.8287203 test losss 4.158004
# each epoch:train loss 3.4708157 test losss 4.041974
# each epoch:train loss 3.0145435 test losss 3.2188256
# each epoch:train loss 2.6627593 test losss 2.9656477
# each epoch:train loss 2.364226 test losss 2.5610638
# each epoch:train loss 2.140215 test losss 2.4886098
# each epoch:train loss 1.8932357 test losss 2.2092707
# each epoch:train loss 1.7330906 test losss 2.059811
# each epoch:train loss 1.4760932 test losss 1.6189955
# each epoch:train loss 1.3193511 test losss 1.4350464
# each epoch:train loss 1.210603 test losss 1.4439423
# each epoch:train loss 1.0623337 test losss 1.1250329
# each epoch:train loss 0.94512886 test losss 1.1265762
# each epoch:train loss 0.8291143 test losss 0.95143837
# each epoch:train loss 0.7584237 test losss 0.91601837
# each epoch:train loss 0.6633194 test losss 0.7603634
# each epoch:train loss 0.5939029 test losss 0.6836447
# each epoch:train loss 0.5487033 test losss 0.67453516
# each epoch:train loss 0.4807245 test losss 0.5870922
# each epoch:train loss 0.42773706 test losss 0.5051615
# each epoch:train loss 0.38900462 test losss 0.48006776
# each epoch:train loss 0.3458729 test losss 0.4214393
# each epoch:train loss 0.31192464 test losss 0.38354537
# each epoch:train loss 0.28014043 test losss 0.34106183
# each epoch:train loss 0.25313625 test losss 0.30443195
# each epoch:train loss 0.22835627 test losss 0.27959704
# each epoch:train loss 0.2089249 test losss 0.26358116
# each epoch:train loss 0.19013038 test losss 0.22228716
# each epoch:train loss 0.17183173 test losss 0.20307386
# each epoch:train loss 0.15376091 test losss 0.18964027
# each epoch:train loss 0.14010304 test losss 0.17080761
# each epoch:train loss 0.12874341 test losss 0.16495399
# each epoch:train loss 0.11571536 test losss 0.14287509
# each epoch:train loss 0.10580178 test losss 0.12984328
# each epoch:train loss 0.096527375 test losss 0.11924267
# each epoch:train loss 0.08843002 test losss 0.11369762
# each epoch:train loss 0.08042858 test losss 0.102583654
# each epoch:train loss 0.073837675 test losss 0.09206788
# each epoch:train loss 0.06756019 test losss 0.085962094
# each epoch:train loss 0.06518003 test losss 0.075812265
# each epoch:train loss 0.06023041 test losss 0.0697487
# each epoch:train loss 0.052600008 test losss 0.067176595
# each epoch:train loss 0.048515297 test losss 0.061810426
# each epoch:train loss 0.044995442 test losss 0.05632602
# each epoch:train loss 0.04151661 test losss 0.052461877
# each epoch:train loss 0.038461316 test losss 0.049376067
# each epoch:train loss 0.0356618 test losss 0.045612916
# each epoch:train loss 0.033355612 test losss 0.043189153
# each epoch:train loss 0.0315238 test losss 0.038286615
# each epoch:train loss 0.028866276 test losss 0.037100684
# each epoch:train loss 0.026867772 test losss 0.0340071
# each epoch:train loss 0.025304692 test losss 0.031397946
# each epoch:train loss 0.02354862 test losss 0.029904824
# each epoch:train loss 0.023325764 test losss 0.02693907
# each epoch:train loss 0.020762341 test losss 0.026230393
# each epoch:train loss 0.019570148 test losss 0.024263347
# each epoch:train loss 0.018484108 test losss 0.022752421
# each epoch:train loss 0.017806524 test losss 0.021145998
# each epoch:train loss 0.017069057 test losss 0.019900864
# each epoch:train loss 0.01591807 test losss 0.01886302
# each epoch:train loss 0.01476695 test losss 0.018233053
# each epoch:train loss 0.014037764 test losss 0.017097697
# each epoch:train loss 0.013571425 test losss 0.016815713
# each epoch:train loss 0.012726456 test losss 0.015587872
# each epoch:train loss 0.012173021 test losss 0.014568933
# each epoch:train loss 0.011641616 test losss 0.01418256
# each epoch:train loss 0.011309629 test losss 0.013091333
# each epoch:train loss 0.010765264 test losss 0.013068561
# each epoch:train loss 0.01024605 test losss 0.012247779
# each epoch:train loss 0.009851684 test losss 0.011712042
# each epoch:train loss 0.009492892 test losss 0.011243823
# each epoch:train loss 0.009214081 test losss 0.010969847
# each epoch:train loss 0.008941793 test losss 0.010186805
# each epoch:train loss 0.008577659 test losss 0.010056261
# each epoch:train loss 0.008293957 test losss 0.009631903
# each epoch:train loss 0.008040913 test losss 0.009256745
# each epoch:train loss 0.007831839 test losss 0.009060197
# each epoch:train loss 0.0076648504 test losss 0.008864839
# each epoch:train loss 0.007817969 test losss 0.008203317
# each epoch:train loss 0.007235088 test losss 0.008235641
# each epoch:train loss 0.007503895 test losss 0.0077299154
# each epoch:train loss 0.0069048614 test losss 0.0077583166
# each epoch:train loss 0.0069681806 test losss 0.007334189
# each epoch:train loss 0.0066519026 test losss 0.0072331266
# each epoch:train loss 0.006705403 test losss 0.006995427
# each epoch:train loss 0.0064023524 test losss 0.007110728
# each epoch:train loss 0.0062750555 test losss 0.006940265
# each epoch:train loss 0.0061594825 test losss 0.0066953874
# each epoch:train loss 0.006079263 test losss 0.0065377075
# each epoch:train loss 0.006026343 test losss 0.006388773
# each epoch:train loss 0.0058920737 test losss 0.00640007
# each epoch:train loss 0.005822687 test losss 0.0063296584
# final epoch:train loss 0.005822687 test loss 0.0063296584
# weight: [[ 1.2647591 -3.3838642  5.581425 ]]
# bias: [4.9648757]

# %%
fit_and_plot(features[:n_train, :], features[n_train:, :], labels[:n_train],
             labels[n_train:])
# Out:
# each epoch:train loss 237.05957 test losss 171.18599
# each epoch:train loss 205.98451 test losss 149.94424
# each epoch:train loss 181.54755 test losss 133.36024
# each epoch:train loss 162.36139 test losss 120.43863
# each epoch:train loss 146.95325 test losss 110.1989
# each epoch:train loss 134.92046 test losss 102.2944
# each epoch:train loss 125.20459 test losss 96.028076
# each epoch:train loss 117.57509 test losss 91.190704
# each epoch:train loss 111.455315 test losss 87.39729
# each epoch:train loss 106.66974 test losss 84.5025
# each epoch:train loss 102.815475 test losss 82.24508
# each epoch:train loss 99.762 test losss 80.52503
# each epoch:train loss 97.23117 test losss 79.16669
# each epoch:train loss 95.20495 test losss 78.14283
# each epoch:train loss 93.69919 test losss 77.414085
# each epoch:train loss 92.37074 test losss 76.82964
# each epoch:train loss 91.35485 test losss 76.421684
# each epoch:train loss 90.49809 test losss 76.12434
# each epoch:train loss 89.78251 test losss 75.91382
# each epoch:train loss 89.26451 test losss 75.76901
# each epoch:train loss 88.775635 test losss 75.68472
# each epoch:train loss 88.38403 test losss 75.64739
# each epoch:train loss 88.075905 test losss 75.6443
# each epoch:train loss 87.826385 test losss 75.65294
# each epoch:train loss 87.65123 test losss 75.667076
# each epoch:train loss 87.46617 test losss 75.72053
# each epoch:train loss 87.3336 test losss 75.76221
# each epoch:train loss 87.23029 test losss 75.802635
# each epoch:train loss 87.14651 test losss 75.83502
# each epoch:train loss 87.064316 test losss 75.89292
# each epoch:train loss 86.9917 test losss 75.95954
# each epoch:train loss 86.93083 test losss 76.02659
# each epoch:train loss 86.8847 test losss 76.07985
# each epoch:train loss 86.84845 test losss 76.12501
# each epoch:train loss 86.814514 test losss 76.17962
# each epoch:train loss 86.78795 test losss 76.22518
# each epoch:train loss 86.771484 test losss 76.24182
# each epoch:train loss 86.754944 test losss 76.269455
# each epoch:train loss 86.73886 test losss 76.31246
# each epoch:train loss 86.72143 test losss 76.36714
# each epoch:train loss 86.7069 test losss 76.42389
# each epoch:train loss 86.70006 test losss 76.43349
# each epoch:train loss 86.69169 test losss 76.468185
# each epoch:train loss 86.68388 test losss 76.49767
# each epoch:train loss 86.677956 test losss 76.523705
# each epoch:train loss 86.67452 test losss 76.52774
# each epoch:train loss 86.6724 test losss 76.528366
# each epoch:train loss 86.66602 test losss 76.57781
# each epoch:train loss 86.66339 test losss 76.586525
# each epoch:train loss 86.659935 test losss 76.62027
# each epoch:train loss 86.65778 test losss 76.644806
# each epoch:train loss 86.65496 test losss 76.67485
# each epoch:train loss 86.65363 test losss 76.673225
# each epoch:train loss 86.65353 test losss 76.657196
# each epoch:train loss 86.653046 test losss 76.657135
# each epoch:train loss 86.65108 test losss 76.68862
# each epoch:train loss 86.64988 test losss 76.71765
# each epoch:train loss 86.64882 test losss 76.74114
# each epoch:train loss 86.64873 test losss 76.722626
# each epoch:train loss 86.64796 test losss 76.738434
# each epoch:train loss 86.64768 test losss 76.740715
# each epoch:train loss 86.64724 test losss 76.752106
# each epoch:train loss 86.64682 test losss 76.760704
# each epoch:train loss 86.64702 test losss 76.747444
# each epoch:train loss 86.64652 test losss 76.78128
# each epoch:train loss 86.64658 test losss 76.76849
# each epoch:train loss 86.64652 test losss 76.76077
# each epoch:train loss 86.64673 test losss 76.749306
# each epoch:train loss 86.64725 test losss 76.73246
# each epoch:train loss 86.646385 test losss 76.75738
# each epoch:train loss 86.645966 test losss 76.7728
# each epoch:train loss 86.646095 test losss 76.76681
# each epoch:train loss 86.64693 test losss 76.73991
# each epoch:train loss 86.64737 test losss 76.72872
# each epoch:train loss 86.64722 test losss 76.73289
# each epoch:train loss 86.64675 test losss 76.74502
# each epoch:train loss 86.646576 test losss 76.750305
# each epoch:train loss 86.64669 test losss 76.74802
# each epoch:train loss 86.64588 test losss 76.77393
# each epoch:train loss 86.645676 test losss 76.78271
# each epoch:train loss 86.645195 test losss 76.813995
# each epoch:train loss 86.64513 test losss 76.82907
# each epoch:train loss 86.64513 test losss 76.81937
# each epoch:train loss 86.64523 test losss 76.80881
# each epoch:train loss 86.64529 test losss 76.80519
# each epoch:train loss 86.645676 test losss 76.783035
# each epoch:train loss 86.64529 test losss 76.80475
# each epoch:train loss 86.645096 test losss 76.82458
# each epoch:train loss 86.64505 test losss 76.85469
# each epoch:train loss 86.64522 test losss 76.873314
# each epoch:train loss 86.64545 test losss 76.89074
# each epoch:train loss 86.64503 test losss 76.859924
# each epoch:train loss 86.64501 test losss 76.83951
# each epoch:train loss 86.64524 test losss 76.81696
# each epoch:train loss 86.64546 test losss 76.801605
# each epoch:train loss 86.6459 test losss 76.78767
# each epoch:train loss 86.645096 test losss 76.82997
# each epoch:train loss 86.64503 test losss 76.83721
# each epoch:train loss 86.64503 test losss 76.83559
# each epoch:train loss 86.64504 test losss 76.84395
# final epoch:train loss 86.64504 test loss 76.84395
# weight: [[18.313297]]
# bias: [1.4271927]

# %%
fit_and_plot(poly_features[0:2, :], poly_features[n_train:, :], labels[0:2],
             labels[n_train:])
# Out:
# each epoch:train loss 9.3434 test losss 193.06265
# each epoch:train loss 9.214367 test losss 191.21944
# each epoch:train loss 9.089883 test losss 189.41432
# each epoch:train loss 8.969748 test losss 187.64622
# each epoch:train loss 8.853771 test losss 185.91411
# each epoch:train loss 8.74177 test losss 184.21689
# each epoch:train loss 8.633569 test losss 182.55362
# each epoch:train loss 8.529001 test losss 180.92332
# each epoch:train loss 8.427909 test losss 179.32506
# each epoch:train loss 8.330137 test losss 177.75793
# each epoch:train loss 8.235546 test losss 176.22107
# each epoch:train loss 8.143991 test losss 174.71365
# each epoch:train loss 8.055345 test losss 173.23482
# each epoch:train loss 7.9694777 test losss 171.78383
# each epoch:train loss 7.8862705 test losss 170.35988
# each epoch:train loss 7.805608 test losss 168.96225
# each epoch:train loss 7.7273793 test losss 167.5902
# each epoch:train loss 7.6514807 test losss 166.24307
# each epoch:train loss 7.5778112 test losss 164.92018
# each epoch:train loss 7.506275 test losss 163.62083
# each epoch:train loss 7.436781 test losss 162.34444
# each epoch:train loss 7.3692417 test losss 161.0904
# each epoch:train loss 7.3035736 test losss 159.8581
# each epoch:train loss 7.2396975 test losss 158.64696
# each epoch:train loss 7.177536 test losss 157.45644
# each epoch:train loss 7.1170197 test losss 156.286
# each epoch:train loss 7.058076 test losss 155.13509
# each epoch:train loss 7.00064 test losss 154.00323
# each epoch:train loss 6.944649 test losss 152.88994
# each epoch:train loss 6.890042 test losss 151.7947
# each epoch:train loss 6.8367605 test losss 150.71709
# each epoch:train loss 6.784751 test losss 149.65665
# each epoch:train loss 6.7339597 test losss 148.61292
# each epoch:train loss 6.684337 test losss 147.58551
# each epoch:train loss 6.6358347 test losss 146.574
# each epoch:train loss 6.588407 test losss 145.578
# each epoch:train loss 6.542011 test losss 144.5971
# each epoch:train loss 6.4966025 test losss 143.63097
# each epoch:train loss 6.452144 test losss 142.6792
# each epoch:train loss 6.408596 test losss 141.74147
# each epoch:train loss 6.365924 test losss 140.81743
# each epoch:train loss 6.32409 test losss 139.90674
# each epoch:train loss 6.2830644 test losss 139.0091
# each epoch:train loss 6.242812 test losss 138.12416
# each epoch:train loss 6.2033043 test losss 137.25165
# each epoch:train loss 6.164512 test losss 136.39125
# each epoch:train loss 6.1264076 test losss 135.54268
# each epoch:train loss 6.0889645 test losss 134.70567
# each epoch:train loss 6.0521564 test losss 133.87997
# each epoch:train loss 6.0159616 test losss 133.06528
# each epoch:train loss 5.980355 test losss 132.26135
# each epoch:train loss 5.9453154 test losss 131.46794
# each epoch:train loss 5.910821 test losss 130.68483
# each epoch:train loss 5.8768525 test losss 129.91174
# each epoch:train loss 5.8433895 test losss 129.14848
# each epoch:train loss 5.8104153 test losss 128.3948
# each epoch:train loss 5.777911 test losss 127.65052
# each epoch:train loss 5.74586 test losss 126.91541
# each epoch:train loss 5.7142467 test losss 126.189255
# each epoch:train loss 5.683055 test losss 125.47188
# each epoch:train loss 5.6522713 test losss 124.76308
# each epoch:train loss 5.6218815 test losss 124.06267
# each epoch:train loss 5.591871 test losss 123.37046
# each epoch:train loss 5.5622272 test losss 122.68629
# each epoch:train loss 5.532939 test losss 122.00998
# each epoch:train loss 5.503993 test losss 121.34135
# each epoch:train loss 5.47538 test losss 120.680244
# each epoch:train loss 5.447088 test losss 120.02652
# each epoch:train loss 5.4191065 test losss 119.38001
# each epoch:train loss 5.3914266 test losss 118.740555
# each epoch:train loss 5.364038 test losss 118.10804
# each epoch:train loss 5.3369327 test losss 117.48228
# each epoch:train loss 5.3101015 test losss 116.86315
# each epoch:train loss 5.2835364 test losss 116.250534
# each epoch:train loss 5.25723 test losss 115.64429
# each epoch:train loss 5.2311735 test losss 115.04428
# each epoch:train loss 5.2053604 test losss 114.45039
# each epoch:train loss 5.1797833 test losss 113.86249
# each epoch:train loss 5.154437 test losss 113.28048
# each epoch:train loss 5.1293135 test losss 112.70421
# each epoch:train loss 5.1044083 test losss 112.13362
# each epoch:train loss 5.079715 test losss 111.56856
# each epoch:train loss 5.0552273 test losss 111.00892
# each epoch:train loss 5.030941 test losss 110.45463
# each epoch:train loss 5.00685 test losss 109.90556
# each epoch:train loss 4.98295 test losss 109.36163
# each epoch:train loss 4.9592366 test losss 108.82272
# each epoch:train loss 4.9357047 test losss 108.28877
# each epoch:train loss 4.91235 test losss 107.75965
# each epoch:train loss 4.889169 test losss 107.235306
# each epoch:train loss 4.8661575 test losss 106.71562
# each epoch:train loss 4.843312 test losss 106.20055
# each epoch:train loss 4.820627 test losss 105.689964
# each epoch:train loss 4.7981024 test losss 105.183815
# each epoch:train loss 4.7757316 test losss 104.68202
# each epoch:train loss 4.7535133 test losss 104.184494
# each epoch:train loss 4.731444 test losss 103.69116
# each epoch:train loss 4.709521 test losss 103.201965
# each epoch:train loss 4.68774 test losss 102.71682
# each epoch:train loss 4.6661 test losss 102.23566
# final epoch:train loss 4.6661 test loss 102.23566
# weight: [[ 0.7135079 -1.2151551  1.4419432]]
# bias: [0.3954572]
